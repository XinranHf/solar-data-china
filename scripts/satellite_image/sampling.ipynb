# %% [markdown]
# # Sampling

# %% [markdown]
# The satellite imagery data used in this project was obtained from Sentinel-2 using Google Earth Engine (GEE).
# You can find the code used for data extraction here: [GEE Sentinel-2 Extraction Code](https://code.earthengine.google.com/c11abab413d190dc51fb51bb76540713) and [GEE Sentienl-2 Augmentation code](https://code.earthengine.google.com/4b8c43c9e7234ece1257f80c8d7cf56b?hl=fr)
#
# After downloading, the imagery was divided into 256x256 pixel tiles using QGIS to facilitate processing and annotation.
#
# In the following sections, we will continue with the labelling process and prepare the datasets for training, validation, and testing.

# %% [markdown]
# ## Setup

# %%
pip install scikit-image
# Out:
# Requirement already satisfied: scikit-image in c:\users\charl\anaconda3\lib\site-packages (0.25.2)
# Requirement already satisfied: numpy>=1.24 in c:\users\charl\anaconda3\lib\site-packages (from scikit-image) (1.26.4)
# Requirement already satisfied: scipy>=1.11.4 in c:\users\charl\anaconda3\lib\site-packages (from scikit-image) (1.13.1)
# Requirement already satisfied: networkx>=3.0 in c:\users\charl\anaconda3\lib\site-packages (from scikit-image) (3.3)
# Requirement already satisfied: pillow>=10.1 in c:\users\charl\anaconda3\lib\site-packages (from scikit-image) (10.4.0)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in c:\users\charl\anaconda3\lib\site-packages (from scikit-image) (2.33.1)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\charl\anaconda3\lib\site-packages (from scikit-image) (2023.4.12)
# Requirement already satisfied: packaging>=21 in c:\users\charl\anaconda3\lib\site-packages (from scikit-image) (24.1)
# Requirement already satisfied: lazy-loader>=0.4 in c:\users\charl\anaconda3\lib\site-packages (from scikit-image) (0.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import geopandas as gpd
import rasterio
import numpy as np
import os
import glob
from skimage.feature import graycomatrix, graycoprops
import geopandas as gpd
from rasterio.features import rasterize
from shapely.geometry import box
from pathlib import Path
import shapely.wkt
import matplotlib.pyplot as plt
from rasterio.merge import merge
from rasterio.warp import transform
import math
import matplotlib.patches as mpatches

# %% [markdown]
# ## Overview

# %%
# County, Prefecture, Tiff, Tiles data
data = [
    {"County": "Shuangfeng", "Prefecture": "Loudi", "Tiff": 4, "Tiles": 725},
    {"County": "Baihe", "Prefecture": "Ankang", "Tiff": 2, "Tiles": 475},
    {"County": "Hanbin", "Prefecture": "Ankang", "Tiff": 9, "Tiles": 1872},
    {"County": "Yiyuan", "Prefecture": "Zibo", "Tiff": 4, "Tiles": 806},
    {"County": "Cao", "Prefecture": "Heze", "Tiff": 4, "Tiles": 891},
    {"County": "Yuechi", "Prefecture": "Guang'an", "Tiff": 4, "Tiles": 729},
    {"County": "Jingyang", "Prefecture": "LiangshanYi", "Tiff": 4, "Tiles": 725},
    {"County": "LanpingBaiandPumi", "Prefecture": "NujiangLisu", "Tiff": 6, "Tiles": 1440},
    {"County": "Yongshan", "Prefecture": "Zhaotong", "Tiff": 6, "Tiles": 1700},
    {"County": "Yanjin", "Prefecture": "Xinxiang", "Tiff": 4, "Tiles": 420},
    {"County": "Yuanling", "Prefecture": "Huaihua", "Tiff": 9, "Tiles": 2068},
    {"County": "Sheqi", "Prefecture": "Nanyang", "Tiff": 2, "Tiles": 380},
    {"County": "Gushi", "Prefecture": "Xinyang", "Tiff": 6, "Tiles": 1118},
    {"County": "Xuanhua", "Prefecture": "Zhangjiakou", "Tiff": 4, "Tiles": 1368},
    {"County": "Daming", "Prefecture": "Handan", "Tiff": 4, "Tiles": 529},
    {"County": "Heshui", "Prefecture": "Qingyang", "Tiff": 6, "Tiles": 1672},
]

df = pd.DataFrame(data)

# %%
print(df['Tiles'].sum())
# Out:
# 16918

# %%
total_sample_tiles_1000 = 1000 
total_sample_tiles_2000 = 2000
total_sample_tiles_5000 = 5000
total_sample_tiles_10000 = 10000

# Create a new DataFrame for proportional sampling
df_proportion = df.copy()
df_proportion['Proportion'] = df_proportion['Tiles'] / df_proportion['Tiles'].sum()
df_proportion['SampledTiles_1000'] = (df_proportion['Proportion'] * total_sample_tiles_1000).round().astype(int)
df_proportion['SampledTiles_2000'] = (df_proportion['Proportion'] * total_sample_tiles_2000).round().astype(int)
df_proportion['SampledTiles_5000'] = (df_proportion['Proportion'] * total_sample_tiles_5000).round().astype(int)
df_proportion['SampledTiles_10000'] = (df_proportion['Proportion'] * total_sample_tiles_10000).round().astype(int)

print(df_proportion[['County', 'Tiles', 'Proportion', 'SampledTiles_1000','SampledTiles_2000','SampledTiles_5000','SampledTiles_10000']])
# Out:
#                County  Tiles  Proportion  SampledTiles_1000  \
# 0          Shuangfeng    725    0.042854                 43
# 1               Baihe    475    0.028077                 28
# 2              Hanbin   1872    0.110651                111
# 3              Yiyuan    806    0.047642                 48
# 4                 Cao    891    0.052666                 53
# 5              Yuechi    729    0.043090                 43
# 6            Jingyang    725    0.042854                 43
# 7   LanpingBaiandPumi   1440    0.085116                 85
# 8            Yongshan   1700    0.100485                100
# 9              Yanjin    420    0.024826                 25
# 10           Yuanling   2068    0.122237                122
# 11              Sheqi    380    0.022461                 22
# 12              Gushi   1118    0.066083                 66
# 13            Xuanhua   1368    0.080861                 81
# 14             Daming    529    0.031268                 31
# 15             Heshui   1672    0.098830                 99
#
#     SampledTiles_2000  SampledTiles_5000  SampledTiles_10000
# 0                  86                214                 429
# 1                  56                140                 281
# 2                 221                553                1107
# 3                  95                238                 476
# 4                 105                263                 527
# 5                  86                215                 431
# 6                  86                214                 429
# 7                 170                426                 851
# 8                 201                502                1005
# 9                  50                124                 248
# 10                244                611                1222
# 11                 45                112                 225
# 12                132                330                 661
# 13                162                404                 809
# 14                 63                156                 313
# 15                198                494                 988

# %% [markdown]
# ## Find positive Sample

# %%
focus_counties = pd.read_csv('../../focus_counties.csv')

focus_counties
# Out:
#     province   prefecture             county  \
# 0      Hebei       Handan             Daming
# 1      Hebei  Zhangjiakou            Xuanhua
# 2      Henan      Xinyang              Gushi
# 3      Henan      Nanyang              Sheqi
# 4      Henan     Xinxiang             Yanjin
# 5      Hunan      Huaihua           Yuanling
# 6      Hunan        Loudi         Shuangfeng
# 7   Shandong         Zibo             Yiyuan
# 8   Shandong         Heze                Cao
# 9    Shaanxi       Ankang              Baihe
# 10   Sichuan     Guang'an             Yuechi
# 11   Sichuan  LiangshanYi           Jingyang
# 12    Yunnan  NujiangLisu  LanpingBaiandPumi
# 13    Yunnan     Zhaotong           Yongshan
# 14     Gansu     Qingyang             Heshui
# 15   Shaanxi       Ankang             Hanbin
#
#                                              geometry
# 0   {'type': 'MultiPolygon', 'coordinates': [(((11...
# 1   {'type': 'MultiPolygon', 'coordinates': [(((11...
# 2   {'type': 'MultiPolygon', 'coordinates': [(((11...
# 3   {'type': 'MultiPolygon', 'coordinates': [(((11...
# 4   {'type': 'MultiPolygon', 'coordinates': [(((11...
# 5   {'type': 'MultiPolygon', 'coordinates': [(((11...
# 6   {'type': 'MultiPolygon', 'coordinates': [(((11...
# 7   {'type': 'MultiPolygon', 'coordinates': [(((11...
# 8   {'type': 'MultiPolygon', 'coordinates': [(((11...
# 9   {'type': 'MultiPolygon', 'coordinates': [(((11...
# 10  {'type': 'MultiPolygon', 'coordinates': [(((10...
# 11  {'type': 'MultiPolygon', 'coordinates': [(((10...
# 12  {'type': 'MultiPolygon', 'coordinates': [(((99...
# 13  {'type': 'MultiPolygon', 'coordinates': [(((10...
# 14  {'type': 'Polygon', 'coordinates': (((107.8433...
# 15  {'type': 'Polygon', 'coordinates': (((108.5039...

# %%
chinapv_vectorized_2020 = gpd.read_file('../../data/data_processed/chinapv_vectorized_2020.geojson')

# %%
# Adjust county names for special cases before matching
chinapv_vectorized_2020_adj = chinapv_vectorized_2020.copy()
chinapv_vectorized_2020_adj['County'] = chinapv_vectorized_2020_adj.apply(
    lambda row: 'Ankang' if row['County'].lower() == 'hanbin' else (
        'Qingyang' if row['County'].lower() == 'heshui' else row['County']
    ),
    axis=1
)

positive_samples= chinapv_vectorized_2020_adj[
    chinapv_vectorized_2020_adj[['Province', 'Prefecture', 'County']].apply(
        lambda row: ((row['Province'], row['Prefecture'], row['County'])) in 
        list(zip(focus_counties['province'], focus_counties['prefecture'], focus_counties['county'])), axis=1)
]

# %%
positive_samples.head()
# Out:
#      Latitude  Longitude Province      Area  Perimeter  urban   Prefecture  \
# 112   26.4986    99.4311   Yunnan  0.264018   4.715096      0  NujiangLisu
# 432   31.9221   115.9240    Henan  0.002772   0.321835      0      Xinyang
# 475   32.2910   115.8070    Henan  0.016298   0.554750      0      Xinyang
# 578   31.8983   115.8740    Henan  0.009142   0.382482      1      Xinyang
# 582   31.9766   115.5860    Henan  0.009134   0.399608      0      Xinyang
#
#                 County                                           geometry
# 112  LanpingBaiandPumi  POLYGON Z ((99.431 26.502 0, 99.432 26.502 0, ...
# 432              Gushi  POLYGON Z ((115.92 31.915 0, 115.92 31.915 0, ...
# 475              Gushi  POLYGON Z ((115.81 32.29 0, 115.81 32.29 0, 11...
# 578              Gushi  POLYGON Z ((115.87 31.899 0, 115.87 31.898 0, ...
# 582              Gushi  POLYGON Z ((115.59 31.976 0, 115.59 31.976 0, ...

# %%
positive_samples.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 126 entries, 112 to 10686
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Latitude    126 non-null    float64
#  1   Longitude   126 non-null    float64
#  2   Province    126 non-null    object
#  3   Area        126 non-null    float64
#  4   Perimeter   126 non-null    float64
#  5   urban       126 non-null    int32
#  6   Prefecture  126 non-null    object
#  7   County      126 non-null    object
#  8   geometry    126 non-null    geometry
# dtypes: float64(4), geometry(1), int32(1), object(3)
# memory usage: 9.4+ KB

# %%
positive_samples_augmented= chinapv_vectorized_2020[
    chinapv_vectorized_2020[['Province', 'Prefecture']].apply(
        lambda row: ((row['Province'], row['Prefecture'])) in 
        list(zip(focus_counties['province'], focus_counties['prefecture'])), axis=1)
]

# %%
positive_samples_augmented.head()
# Out:
#      Latitude  Longitude Province      Area  Perimeter  urban   Prefecture  \
# 41    41.5087   114.0300    Hebei  5.082834  16.732663      0  Zhangjiakou
# 111   41.4512   113.9540    Hebei  0.561444   4.396728      0  Zhangjiakou
# 112   26.4986    99.4311   Yunnan  0.264018   4.715096      0  NujiangLisu
# 124   41.4491   113.9690    Hebei  0.496769   3.611616      1  Zhangjiakou
# 131   41.5727   114.9820    Hebei  0.362617   2.987831      1  Zhangjiakou
#
#                 County                                           geometry
# 41             Shangyi  POLYGON Z ((114.02 41.52 0, 114.02 41.519 0, 1...
# 111            Shangyi  POLYGON Z ((113.95 41.456 0, 113.95 41.455 0, ...
# 112  LanpingBaiandPumi  POLYGON Z ((99.431 26.502 0, 99.432 26.502 0, ...
# 124            Shangyi  POLYGON Z ((113.97 41.453 0, 113.97 41.452 0, ...
# 131             Guyuan  POLYGON Z ((114.98 41.575 0, 114.98 41.575 0, ...

# %%
positive_samples_augmented.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 680 entries, 41 to 10733
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Latitude    680 non-null    float64
#  1   Longitude   680 non-null    float64
#  2   Province    680 non-null    object
#  3   Area        680 non-null    float64
#  4   Perimeter   680 non-null    float64
#  5   urban       680 non-null    int32
#  6   Prefecture  680 non-null    object
#  7   County      680 non-null    object
#  8   geometry    680 non-null    geometry
# dtypes: float64(4), geometry(1), int32(1), object(3)
# memory usage: 50.5+ KB

# %%
# Group by "Prefecture" and count the number of solar panel samples per prefecture

# Count the number of samples per prefecture in each DataFrame
nb_prefecture = positive_samples.groupby("Prefecture")['geometry'].count().rename('nb_positive')
nb_prefecture_augmented = positive_samples_augmented.groupby("Prefecture")['geometry'].count().rename('nb_augmented')

# Combine the counts into a single DataFrame
comparaison_augmented = pd.concat([nb_prefecture, nb_prefecture_augmented], axis=1)

# Replace NaN values with 0
comparaison_augmented = comparaison_augmented.fillna(0)

# Calculate the difference
comparaison_augmented['difference'] = comparaison_augmented['nb_augmented'] - comparaison_augmented['nb_positive']

comparaison_augmented
# Out:
#              nb_positive  nb_augmented  difference
# Prefecture
# Handan               7.0            47        40.0
# Heze                15.0            46        31.0
# NujiangLisu          6.0             6         0.0
# Xinxiang             2.0            20        18.0
# Xinyang              5.0            15        10.0
# Zhangjiakou         80.0           388       308.0
# Zibo                11.0            36        25.0
# Ankang               0.0             1         1.0
# Huaihua              0.0             2         2.0
# LiangshanYi          0.0            56        56.0
# Loudi                0.0             1         1.0
# Nanyang              0.0            59        59.0
# Qingyang             0.0             3         3.0

# %%
comparaison_augmented.sum()
# Out:
# nb_positive     126.0
# nb_augmented    680.0
# difference      554.0
# dtype: float64

# %%
# Ensure 'Tiles' column is added correctly by aligning index
comparaison_augmented['Tiles'] = df.groupby("Prefecture")['Tiles'].sum()

# Calculate the proportion of tiles per prefecture
comparaison_augmented['Proportion'] = comparaison_augmented['Tiles'] / comparaison_augmented['Tiles'].sum()

# Select only the 'Proportion' and 'nb_augmented' columns for display
comparaison_augmented = comparaison_augmented[['Proportion', 'nb_augmented']]

total_sample = comparaison_augmented['nb_augmented'].sum()
comparaison_augmented['sample_proportional'] =  (comparaison_augmented['Proportion'] * total_sample).round().astype(int)

comparaison_augmented
# Out:
# C:\Users\charl\AppData\Local\Temp\ipykernel_25904\2743737522.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   comparaison_augmented['sample_proportional'] =  (comparaison_augmented['Proportion'] * total_sample).round().astype(int)
#              Proportion  nb_augmented  sample_proportional
# Prefecture
# Handan         0.036510            47                   25
# Heze           0.061495            46                   42
# NujiangLisu    0.099386             6                   68
# Xinxiang       0.028988            20                   20
# Xinyang        0.077162            15                   52
# Zhangjiakou    0.094416           388                   64
# Zibo           0.055628            36                   38
# Ankang         0.161985             1                  110
# Huaihua        0.142729             2                   97
# LiangshanYi    0.050038            56                   34
# Loudi          0.050038             1                   34
# Nanyang        0.026227            59                   18
# Qingyang       0.115398             3                   78

# %% [markdown]
# The difference between the number of samples and the number of proportional samples is sometimes quite large.
# For example, some prefectures like Zhangjiakou are oversampled, while others like Ankang are poorly sampled.
# To address this imbalance:
# - For oversampled prefectures such as Zhangjiakou, we can keep only the urban samples, since our goal is to improve performance on residential/rooftop solar panels.
# - For under-sampled prefectures, we can apply data augmentation or transformations to increase their sample size.

# %%
# For prefecture 'Zhangjiakou', keep only urban=1 for counties that are not the focus county
focus_county = focus_counties.loc[focus_counties['prefecture'] == 'Zhangjiakou', 'county'].iloc[0]

print('Focus county for Zhangjiakou:', focus_county)

# Use positive_samples_augmented for filtering, not positive_samples
mask = ~(
    (positive_samples_augmented['Prefecture'] == 'Zhangjiakou') &
    (positive_samples_augmented['County'] != focus_county) &
    (positive_samples_augmented['urban'] != 1)
)
positive_samples_correction = positive_samples_augmented[mask]
# Out:
# Focus county for Zhangjiakou: Xuanhua

# %%
positive_samples_correction
# Out:
#        Latitude  Longitude  Province      Area  Perimeter  urban   Prefecture  \
# 112     26.4986    99.4311    Yunnan  0.264018   4.715096      0  NujiangLisu
# 124     41.4491   113.9690     Hebei  0.496769   3.611616      1  Zhangjiakou
# 131     41.5727   114.9820     Hebei  0.362617   2.987831      1  Zhangjiakou
# 135     28.1917   102.5010   Sichuan  0.391145   5.752748      0  LiangshanYi
# 153     36.6606   113.6430     Hebei  0.023683   0.670427      0       Handan
# ...         ...        ...       ...       ...        ...    ...          ...
# 10686   36.0884   117.9870  Shandong  0.024399   0.801757      0         Zibo
# 10697   36.6614   118.0890  Shandong  0.065085   1.103224      1         Zibo
# 10698   36.6656   118.0900  Shandong  0.068542   1.104506      1         Zibo
# 10732   26.1767   102.0530   Sichuan  0.012066   0.444242      0  LiangshanYi
# 10733   26.1770   102.0510   Sichuan  0.011978   0.436653      0  LiangshanYi
#
#                   County                                           geometry
# 112    LanpingBaiandPumi  POLYGON Z ((99.431 26.502 0, 99.432 26.502 0, ...
# 124              Shangyi  POLYGON Z ((113.97 41.453 0, 113.97 41.452 0, ...
# 131               Guyuan  POLYGON Z ((114.98 41.575 0, 114.98 41.575 0, ...
# 135                 Xide  POLYGON Z ((102.5 28.196 0, 102.5 28.194 0, 10...
# 153                  She  POLYGON Z ((113.64 36.66 0, 113.64 36.66 0, 11...
# ...                  ...                                                ...
# 10686             Yiyuan  POLYGON Z ((117.99 36.087 0, 117.99 36.087 0, ...
# 10697            Zichuan  POLYGON Z ((118.09 36.662 0, 118.09 36.661 0, ...
# 10698            Zichuan  POLYGON Z ((118.09 36.666 0, 118.09 36.665 0, ...
# 10732              Huili  POLYGON Z ((102.05 26.177 0, 102.05 26.176 0, ...
# 10733              Huili  POLYGON Z ((102.05 26.177 0, 102.05 26.176 0, ...
#
# [395 rows x 9 columns]

# %%
nb_prefecture = positive_samples.groupby("Prefecture")['geometry'].count().rename('nb_positive')
nb_prefecture_augmented = positive_samples_augmented.groupby("Prefecture")['geometry'].count().rename('nb_augmented')
nb_prefecture_augmented_correction = positive_samples_correction.groupby("Prefecture")['geometry'].count().rename('nb_augmented_correction')

# Combine the counts into a single DataFrame
comparaison_correction = pd.concat([nb_prefecture, nb_prefecture_augmented, nb_prefecture_augmented_correction], axis=1)

# Replace NaN values with 0
comparaison_correction = comparaison_correction.fillna(0)

# Calculate the difference
comparaison_correction['difference'] = comparaison_correction['nb_augmented_correction'] - comparaison_correction['nb_positive']

comparaison_correction
# Out:
#              nb_positive  nb_augmented  nb_augmented_correction  difference
# Prefecture
# Handan               7.0            47                       47        40.0
# Heze                15.0            46                       46        31.0
# NujiangLisu          6.0             6                        6         0.0
# Xinxiang             2.0            20                       20        18.0
# Xinyang              5.0            15                       15        10.0
# Zhangjiakou         80.0           388                      103        23.0
# Zibo                11.0            36                       36        25.0
# Ankang               0.0             1                        1         1.0
# Huaihua              0.0             2                        2         2.0
# LiangshanYi          0.0            56                       56        56.0
# Loudi                0.0             1                        1         1.0
# Nanyang              0.0            59                       59        59.0
# Qingyang             0.0             3                        3         3.0

# %%
comparaison_correction.sum()
# Out:
# nb_positive                126.0
# nb_augmented               680.0
# nb_augmented_correction    395.0
# difference                 269.0
# dtype: float64

# %%
# Ensure 'Tiles' column is added correctly by aligning index
comparaison_correction['Tiles'] = df.groupby("Prefecture")['Tiles'].sum()

# Calculate the proportion of tiles per prefecture
comparaison_correction['Proportion'] = comparaison_correction['Tiles'] / comparaison_correction['Tiles'].sum()

# Select only the 'Proportion' and 'nb_augmented_correction' columns for display
comparaison_correction = comparaison_correction[['Proportion', 'nb_augmented_correction']]

total_sample = comparaison_correction['nb_augmented_correction'].sum()
comparaison_correction['sample_proportional'] = (comparaison_correction['Proportion'] * total_sample).round().astype(int)

comparaison_correction
# Out:
# C:\Users\charl\AppData\Local\Temp\ipykernel_25904\2448089649.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   comparaison_correction['sample_proportional'] = (comparaison_correction['Proportion'] * total_sample).round().astype(int)
#              Proportion  nb_augmented_correction  sample_proportional
# Prefecture
# Handan         0.036510                       47                   14
# Heze           0.061495                       46                   24
# NujiangLisu    0.099386                        6                   39
# Xinxiang       0.028988                       20                   11
# Xinyang        0.077162                       15                   30
# Zhangjiakou    0.094416                      103                   37
# Zibo           0.055628                       36                   22
# Ankang         0.161985                        1                   64
# Huaihua        0.142729                        2                   56
# LiangshanYi    0.050038                       56                   20
# Loudi          0.050038                        1                   20
# Nanyang        0.026227                       59                   10
# Qingyang       0.115398                        3                   46

# %% [markdown]
# The sample distribution is still unbalanced across prefectures, but it is improved compared to before.
# Applying further transformations such as data augmentation will also help to balance the dataset.

# %%
positive_samples_correction.to_csv('../../data/positive_samples.csv', index=False, encoding="utf-8")

# %% [markdown]
# ## Clean Tiles

# %% [markdown]
# When clipping the satellite images in Google Earth Engine (GEE) to county boundaries, some tiles may fall completely outside the county area. As a result, all the pixels in these tiles are set to NaN (masked).
# These fully-masked tiles do not contain any valid data and should be removed from further analysis to ensure data quality and avoid errors in subsequent processing steps.

# %%
# Path to the root directory containing all county folders
root_dir = r"D:\solar-data-china\tiles"

# List all county folders (exclude any folder with 'Augmented' in the name, case-insensitive)
county_folders = [
    d for d in os.listdir(root_dir)
    if os.path.isdir(os.path.join(root_dir, d)) and 'augmented' not in d.lower()
]

mosaic_images = []
county_names = []

for county in county_folders:
    county_path = os.path.join(root_dir, county)
    pattern = f"*{county}*.tif"
    # Recursively find all .tif files for this county
    tiles = glob.glob(os.path.join(county_path, '**', pattern), recursive=True)
    print(f"{len(tiles)} tiles found for {county}")

    if len(tiles) == 0:
        print(f"Warning: No tiles found for county {county} in {county_path}")
        continue

    # Open all tiles for reading
    src_files_to_mosaic = [rasterio.open(fp) for fp in tiles]

    # Merge the rasters (rasterio handles geometry and CRS)
    mosaic, out_trans = merge(src_files_to_mosaic)

    # Get the profile (metadata) from one tile for later use
    out_meta = src_files_to_mosaic[0].meta.copy()

    # Close all opened raster files to avoid resource warnings
    for src in src_files_to_mosaic:
        src.close()

    # Store the first band of the mosaic and county name for grid display
    mosaic_images.append(mosaic[0])
    county_names.append(county)

# Display all mosaics in a 4-column grid

n_files = len(mosaic_images)
n_cols = 4
n_rows = int(np.ceil(n_files / n_cols))

fig, axes = plt.subplots(n_rows, n_cols, figsize=(4 * n_cols, 4 * n_rows))
axes = axes.flatten()

for idx, (img, name) in enumerate(zip(mosaic_images, county_names)):
    ax = axes[idx]
    im = ax.imshow(img, cmap='gray')
    ax.set_title(f"{name}", fontsize=10)
    ax.axis('off')

# Hide any unused subplots
for j in range(idx + 1, len(axes)):
    axes[j].axis('off')

plt.tight_layout()
plt.show()
# Out:
# 356 tiles found for Baihe
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[24], line 25
#      22     continue
#      24 # Open all tiles for reading
# ---> 25 src_files_to_mosaic = [rasterio.open(fp) for fp in tiles]
#      27 # Merge the rasters (rasterio handles geometry and CRS)
#      28 mosaic, out_trans = merge(src_files_to_mosaic)
#
# File c:\Users\charl\anaconda3\Lib\site-packages\rasterio\env.py:463, in ensure_env_with_credentials.<locals>.wrapper(*args, **kwds)
#     460     session = DummySession()
#     462 with env_ctor(session=session):
# --> 463     return f(*args, **kwds)
#
# File c:\Users\charl\anaconda3\Lib\site-packages\rasterio\__init__.py:356, in open(fp, mode, driver, width, height, count, crs, transform, dtype, nodata, sharing, opener, **kwargs)
#     353     path = _parse_path(raw_dataset_path)
#     355 if mode == "r":
# --> 356     dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
#     357 elif mode == "r+":
#     358     dataset = get_writer_for_path(path, driver=driver)(
#     359         path, mode, driver=driver, sharing=sharing, **kwargs
#     360     )
#
# File rasterio\\_base.pyx:331, in rasterio._base.DatasetBase.__init__()
#
# File rasterio\\_base.pyx:353, in rasterio._base.DatasetBase._set_attrs_from_dataset_handle()
#
# File rasterio\\_base.pyx:970, in rasterio._base.DatasetBase.meta.__get__()
#
# File rasterio\\_base.pyx:603, in rasterio._base.DatasetBase.nodata.__get__()
#
# File rasterio\\_base.pyx:584, in rasterio._base.DatasetBase.nodatavals.__get__()
#
# File rasterio\\_base.pyx:566, in rasterio._base.DatasetBase.get_nodatavals()
#
# File c:\Users\charl\anaconda3\Lib\logging\__init__.py:1526, in Logger.debug(self, msg, *args, **kwargs)
#    1517 def debug(self, msg, *args, **kwargs):
#    1518     """
#    1519     Log 'msg % args' with severity 'DEBUG'.
#    1520
#    (...)
#    1524     logger.debug("Houston, we have a %s", "thorny problem", exc_info=True)
#    1525     """
# -> 1526     if self.isEnabledFor(DEBUG):
#    1527         self._log(DEBUG, msg, args, **kwargs)
#
# File c:\Users\charl\anaconda3\Lib\logging\__init__.py:1790, in Logger.isEnabledFor(self, level)
#    1787         logger = logger.parent
#    1788     return NOTSET
# -> 1790 def isEnabledFor(self, level):
#    1791     """
#    1792     Is this logger enabled for level 'level'?
#    1793     """
#    1794     if self.disabled:
#
# KeyboardInterrupt:

# %%
# Path to the root directory containing all folders (e.g., Baihe, Cao Augmented, Daming, etc.)
root_dir = r"D:\solar-data-china\tiles"

# %%
for dirpath, dirnames, filenames in os.walk(root_dir):
    nb_nan = 0
    for file in filenames:
        if not file.endswith('.tif'):
            continue
        file_path = os.path.join(dirpath, file)
        try:
            with rasterio.open(file_path) as src:
                tile_img = src.read(1)
                if np.isnan(tile_img).all():
                    nb_nan += 1
        except Exception as e:
            print(f"Error processing {file_path}: {e}")
    print("Number of completely NaN tiles in", dirpath, ":", nb_nan)
# Out:
# Number of completely NaN tiles in D:\solar-data-china\tiles : 0
# Number of completely NaN tiles in D:\solar-data-china\tiles\Augmented : 0
# Number of completely NaN tiles in D:\solar-data-china\tiles\Baihe : 119
# Number of completely NaN tiles in D:\solar-data-china\tiles\Cao : 383
# Number of completely NaN tiles in D:\solar-data-china\tiles\Daming : 232
# Number of completely NaN tiles in D:\solar-data-china\tiles\Gushi : 401
# Number of completely NaN tiles in D:\solar-data-china\tiles\Hanbin : 971
# Number of completely NaN tiles in D:\solar-data-china\tiles\Heshui : 888
# Number of completely NaN tiles in D:\solar-data-china\tiles\Jingyang : 355
# Number of completely NaN tiles in D:\solar-data-china\tiles\LanpingBaiandPumi : 501
# Number of completely NaN tiles in D:\solar-data-china\tiles\Sheqi : 89
# Number of completely NaN tiles in D:\solar-data-china\tiles\Shuangfeng : 324
# Number of completely NaN tiles in D:\solar-data-china\tiles\Xuanhua : 597
# Number of completely NaN tiles in D:\solar-data-china\tiles\Yanjin : 153
# Number of completely NaN tiles in D:\solar-data-china\tiles\Yiyuan : 335
# Number of completely NaN tiles in D:\solar-data-china\tiles\Yongshan : 1052
# Number of completely NaN tiles in D:\solar-data-china\tiles\Yuanling : 803
# Number of completely NaN tiles in D:\solar-data-china\tiles\Yuechi : 371

# %%
deleted_count = 0
deleted_files = []

for dirpath, dirnames, filenames in os.walk(root_dir):
    folder_deleted = 0
    for file in filenames:
        if not file.endswith('.tif'):
            continue
        
        file_path = os.path.join(dirpath, file)

        try:
            # Open the file *read-only*
            with rasterio.open(file_path) as src:
                arr = src.read(1)  # first band
                nodata = src.nodata

                if arr.size == 0:
                    is_empty = True
                else:
                    if nodata is not None:
                        is_empty = np.all((arr == nodata) | np.isnan(arr))
                    else:
                        is_empty = np.isnan(arr).all()

            if is_empty:
                os.remove(file_path)
                deleted_count += 1
                deleted_files.append(file_path)
                folder_deleted += 1
                print(f"Deleted: {file_path}")

        except rasterio.errors.RasterioIOError as e:
            print(f"Could not open {file_path}: {e}")
        except Exception as e:
            print(f"Error processing {file_path}: {e}")

    if folder_deleted > 0:
        print(f"\nDeleted {folder_deleted} empty image(s) in folder: {dirpath}\n")

print(f"\nDeleted {deleted_count} empty `.tif` files in total.\n")
# Out:
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000000000_01_01.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000000000_01_02.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000000000_01_03.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000000000_01_04.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000000000_01_05.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000000000_01_06.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000000000_01_07.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000000000_01_08.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000000000_01_09.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000000000_01_14.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000000000_01_15.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000000000_01_16.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000000000_01_17.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000000000_01_18.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000000000_01_19.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000000000_02_01.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000000000_02_02.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000000000_02_03.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000000000_02_04.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000000000_02_05.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000000000_02_06.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000000000_02_07.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000000000_02_18.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000000000_02_19.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000000000_03_01.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000000000_03_02.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000000000_03_03.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000000000_03_04.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000000000_03_05.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000000000_03_06.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000000000_03_07.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000000000_03_19.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000000000_04_01.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000000000_05_01.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000000000_14_01.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000000000_15_01.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000000000_15_02.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000000000_16_01.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000000000_16_02.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000000000_16_03.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000000000_17_01.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000000000_17_02.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000000000_17_03.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000000000_17_04.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000000000_18_01.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000000000_18_02.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000000000_18_03.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000000000_18_04.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000000000_18_05.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000000000_18_06.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000000000_18_11.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000000000_18_12.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000000000_18_13.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000000000_19_01.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000000000_19_02.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000000000_19_03.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000000000_19_04.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000000000_19_05.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000000000_19_06.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000000000_19_07.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000000000_19_08.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000000000_19_09.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000000000_19_10.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000000000_19_11.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000000000_19_12.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000000000_19_13.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000000000_19_14.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000000000_19_15.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000004864_01_01.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000004864_01_02.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000004864_01_03.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000004864_01_04.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000004864_01_05.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000004864_01_06.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000004864_02_01.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000004864_02_02.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000004864_02_03.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000004864_02_04.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000004864_02_05.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000004864_02_06.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000004864_03_01.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000004864_03_02.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000004864_03_03.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000004864_03_04.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000004864_03_05.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000004864_03_06.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000004864_04_03.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000004864_04_04.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000004864_04_05.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000004864_04_06.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000004864_05_04.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000004864_05_05.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000004864_05_06.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000004864_06_05.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000004864_06_06.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000004864_07_04.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000004864_07_05.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000004864_07_06.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000004864_08_06.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000004864_09_06.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000004864_10_06.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000004864_11_06.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000004864_12_05.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000004864_12_06.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000004864_13_06.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000004864_17_02.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000004864_17_03.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000004864_17_06.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000004864_18_02.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000004864_18_03.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000004864_18_04.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000004864_18_05.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000004864_18_06.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000004864_19_01.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000004864_19_02.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000004864_19_03.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000004864_19_04.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000004864_19_05.tif
# Deleted: D:\solar-data-china\tiles\Baihe\s2_Baihe-0000000000-0000004864_19_06.tif
#
# Deleted 119 empty image(s) in folder: D:\solar-data-china\tiles\Baihe
#
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_01_01.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_01_02.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_01_12.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_01_13.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_01_14.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_01_15.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_01_16.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_01_17.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_01_18.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_01_19.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_02_01.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_02_16.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_02_17.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_02_18.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_02_19.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_03_17.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_03_18.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_03_19.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_06_01.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_06_02.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_06_03.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_07_01.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_07_02.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_07_03.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_08_01.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_08_02.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_09_01.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_09_02.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_09_03.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_09_04.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_10_01.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_10_02.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_10_03.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_10_04.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_11_01.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_11_02.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_11_03.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_11_04.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_12_01.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_12_02.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_12_03.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_12_04.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_12_05.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_12_07.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_12_08.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_13_01.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_13_02.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_13_03.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_13_04.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_13_05.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_13_06.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_13_07.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_13_08.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_13_09.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_13_10.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_14_01.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_14_02.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_14_03.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_14_04.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_14_05.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_14_06.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_14_07.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_14_08.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_14_09.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_14_10.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_14_11.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_15_01.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_15_02.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_15_03.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_15_04.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_15_05.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_15_06.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_15_07.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_15_08.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_15_09.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_15_10.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_15_11.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_15_12.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_16_01.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_16_02.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_16_03.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_16_04.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_16_05.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_16_06.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_16_07.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_16_08.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_16_09.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_16_10.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_16_11.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_16_12.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_16_13.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_17_01.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_17_02.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_17_03.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_17_04.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_17_05.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_17_06.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_17_07.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_17_08.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_17_09.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_17_10.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_17_11.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_17_12.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_17_13.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_18_01.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_18_02.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_18_03.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_18_04.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_18_05.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_18_06.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_18_07.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_18_08.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_18_09.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_18_10.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_18_11.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_18_12.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_18_13.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_19_01.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_19_02.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_19_03.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_19_04.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_19_05.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_19_06.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_19_07.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_19_08.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_19_09.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_19_10.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_19_11.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_19_12.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000000000_19_13.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_01_01.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_01_02.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_01_03.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_01_04.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_01_05.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_01_06.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_01_07.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_01_08.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_01_09.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_01_10.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_01_11.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_01_12.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_01_13.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_01_14.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_02_01.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_02_02.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_02_03.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_02_04.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_02_05.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_02_06.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_02_07.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_02_08.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_02_09.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_02_10.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_02_11.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_02_12.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_02_13.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_02_14.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_03_01.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_03_02.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_03_03.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_03_04.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_03_05.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_03_06.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_03_07.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_03_08.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_03_09.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_03_10.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_03_11.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_03_12.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_03_13.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_03_14.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_04_02.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_04_05.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_04_06.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_04_07.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_04_08.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_04_09.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_04_10.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_04_11.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_04_12.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_04_13.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_04_14.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_05_08.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_05_10.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_05_11.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_05_12.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_05_13.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_05_14.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_06_10.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_06_11.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_06_12.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_06_13.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_06_14.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_07_10.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_07_11.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_07_12.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_07_13.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_07_14.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_08_09.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_08_10.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_08_11.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_08_12.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_08_13.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_08_14.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_09_09.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_09_10.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_09_11.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_09_12.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_09_13.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_09_14.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_10_09.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_10_10.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_10_11.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_10_12.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_10_13.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_10_14.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_11_10.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_11_11.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_11_12.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_11_13.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_11_14.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_12_13.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_12_14.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_13_14.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_16_14.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_17_13.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_17_14.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_18_13.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_18_14.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_19_13.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000000000-0000004864_19_14.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_01_01.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_01_02.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_01_03.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_01_04.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_01_05.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_01_06.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_01_07.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_01_08.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_01_09.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_01_10.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_01_11.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_01_12.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_01_13.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_02_01.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_02_02.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_02_03.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_02_04.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_02_05.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_02_06.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_02_07.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_02_08.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_02_09.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_02_10.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_02_11.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_02_12.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_02_13.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_03_01.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_03_02.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_03_03.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_03_04.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_03_05.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_03_06.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_03_07.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_03_08.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_03_09.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_03_10.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_03_11.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_03_12.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_03_13.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_04_01.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_04_02.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_04_03.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_04_04.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_04_05.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_04_06.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_04_07.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_04_08.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_04_09.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_04_10.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_04_11.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_04_12.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_04_13.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_04_14.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_05_01.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_05_02.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_05_03.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_05_04.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_05_05.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_05_06.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_05_07.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_05_08.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_05_09.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_05_10.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_05_11.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_05_12.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_05_13.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_05_14.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_05_15.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_06_01.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_06_02.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_06_03.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_06_04.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_06_05.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_06_06.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_06_07.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_06_08.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_06_09.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_06_10.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_06_11.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_06_12.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_06_13.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_06_14.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_06_15.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_07_01.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_07_02.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_07_03.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_07_04.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_07_05.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_07_06.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_07_07.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_07_08.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_07_09.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_07_10.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_07_11.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_07_12.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_07_13.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_07_14.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_07_15.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_07_16.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_08_01.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_08_02.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_08_03.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_08_04.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_08_05.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_08_06.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_08_07.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_08_08.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_08_09.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_08_10.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_08_11.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_08_12.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_08_13.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_08_14.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_08_15.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_08_16.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_08_17.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_08_18.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000000000_08_19.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000004864_01_13.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000004864_01_14.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000004864_02_13.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000004864_02_14.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000004864_03_12.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000004864_03_13.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000004864_03_14.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000004864_04_11.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000004864_04_12.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000004864_04_13.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000004864_04_14.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000004864_05_11.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000004864_05_12.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000004864_05_13.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000004864_05_14.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000004864_06_12.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000004864_06_13.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000004864_06_14.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000004864_07_07.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000004864_07_12.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000004864_07_13.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000004864_07_14.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000004864_08_01.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000004864_08_02.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000004864_08_03.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000004864_08_07.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000004864_08_08.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000004864_08_09.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000004864_08_10.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000004864_08_11.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000004864_08_12.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000004864_08_13.tif
# Deleted: D:\solar-data-china\tiles\Cao\s2_Cao-0000004864-0000004864_08_14.tif
#
# Deleted 383 empty image(s) in folder: D:\solar-data-china\tiles\Cao
#
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_01_01.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_01_02.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_01_03.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_01_09.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_01_10.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_01_11.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_01_12.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_01_13.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_01_14.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_01_15.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_01_16.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_01_17.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_01_18.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_01_19.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_02_01.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_02_02.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_02_03.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_02_12.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_02_16.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_02_17.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_02_18.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_02_19.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_03_01.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_03_02.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_03_16.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_03_17.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_03_18.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_03_19.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_04_16.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_04_17.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_04_18.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_04_19.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_05_17.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_05_18.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_05_19.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_06_18.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_06_19.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_07_01.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_07_18.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_07_19.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_08_01.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_08_02.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_08_18.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_08_19.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_09_01.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_09_02.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_09_03.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_09_19.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_10_01.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_10_02.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_10_03.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_10_04.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_11_01.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_11_02.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_11_03.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_11_04.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_12_01.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_12_02.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_12_03.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_12_04.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_13_01.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_13_02.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_13_03.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_13_04.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_14_01.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_14_02.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_14_03.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_14_04.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_15_01.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_15_02.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_15_03.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_15_04.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_15_05.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_16_01.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_16_02.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_16_03.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_16_04.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_16_05.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_17_01.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_17_02.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_17_03.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_17_04.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_17_05.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_17_06.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_17_07.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_18_01.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_18_02.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_18_03.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_18_04.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_18_05.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_18_06.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_18_07.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_18_08.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_18_09.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_18_10.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_18_11.tif
# Deleted: D:\solar-data-china\tiles\Daming\s2_Daming-0000000000-0000000000_18_12.tif
# ...
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000000000-0000004864_14_01.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000000000-0000004864_14_02.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000000000-0000004864_14_03.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000000000-0000004864_14_04.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000000000-0000004864_14_05.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000000000-0000004864_14_06.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000000000-0000004864_14_07.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000000000-0000004864_14_08.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000000000-0000004864_15_02.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000000000-0000004864_15_03.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000000000-0000004864_15_04.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000000000-0000004864_15_05.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000000000-0000004864_15_06.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000000000-0000004864_15_07.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000000000-0000004864_15_08.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000000000-0000004864_16_02.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000000000-0000004864_16_03.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000000000-0000004864_16_04.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000000000-0000004864_16_05.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000000000-0000004864_16_06.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000000000-0000004864_16_07.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000000000-0000004864_16_08.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000000000-0000004864_17_01.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000000000-0000004864_17_02.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000000000-0000004864_17_03.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000000000-0000004864_17_04.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000000000-0000004864_17_05.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000000000-0000004864_17_06.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000000000-0000004864_17_07.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000000000-0000004864_17_08.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000000000-0000004864_18_01.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000000000-0000004864_18_02.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000000000-0000004864_18_03.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000000000-0000004864_18_04.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000000000-0000004864_18_05.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000000000-0000004864_18_06.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000000000-0000004864_18_07.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000000000-0000004864_18_08.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000000000-0000004864_19_01.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000000000-0000004864_19_02.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000000000-0000004864_19_03.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000000000-0000004864_19_04.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000000000-0000004864_19_05.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000000000-0000004864_19_06.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000000000-0000004864_19_07.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000000000-0000004864_19_08.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_01_01.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_01_02.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_01_03.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_01_04.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_01_05.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_01_06.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_01_07.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_01_08.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_01_09.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_01_10.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_01_11.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_01_12.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_01_13.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_02_01.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_02_02.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_02_03.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_02_04.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_02_05.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_02_06.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_02_07.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_02_08.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_02_09.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_02_10.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_02_11.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_02_12.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_02_13.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_03_01.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_03_02.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_03_03.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_03_04.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_03_05.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_03_06.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_03_07.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_03_08.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_03_09.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_03_10.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_03_11.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_03_12.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_03_13.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_03_14.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_04_01.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_04_02.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_04_03.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_04_04.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_04_05.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_04_06.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_04_07.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_04_08.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_04_09.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_04_10.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_04_11.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_04_12.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_04_13.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_05_01.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_05_02.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_05_03.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_05_04.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_05_05.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_05_06.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_05_07.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_05_08.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_05_09.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_05_10.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_05_11.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_05_12.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_05_13.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_06_01.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_06_02.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_06_03.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_06_04.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_06_05.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_06_06.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_06_07.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_06_08.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_06_09.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_06_10.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_06_11.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_06_12.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_06_13.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_07_01.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_07_02.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_07_03.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_07_04.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_07_05.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_07_06.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_07_07.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_07_08.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_07_09.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_07_10.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_07_11.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_07_12.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_07_13.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_07_14.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_08_01.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_08_02.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_08_03.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_08_04.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_08_05.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_08_06.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_08_07.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_08_08.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_08_09.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_08_10.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_08_11.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_08_12.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_08_13.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_08_14.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_08_15.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_08_16.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_08_17.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_08_18.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000000000_08_19.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000004864_1_2.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000004864_1_3.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000004864_1_4.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000004864_1_5.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000004864_1_6.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000004864_1_7.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000004864_1_8.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000004864_2_3.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000004864_2_6.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000004864_2_7.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000004864_2_8.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000004864_3_6.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000004864_3_7.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000004864_3_8.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000004864_4_7.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000004864_4_8.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000004864_5_7.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000004864_5_8.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000004864_6_6.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000004864_6_7.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000004864_6_8.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000004864_7_1.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000004864_7_6.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000004864_7_7.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000004864_7_8.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000004864_8_1.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000004864_8_2.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000004864_8_3.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000004864_8_6.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000004864_8_7.tif
# Deleted: D:\solar-data-china\tiles\Yuechi\s2_Yuechi-0000004864-0000004864_8_8.tif
#
# Deleted 371 empty image(s) in folder: D:\solar-data-china\tiles\Yuechi
#
#
# Deleted 6603 empty `.tif` files in total.

# %% [markdown]
# ## Calculate additional indices

# %% [markdown]
# At this stage, I have downloaded my satellite image data from Google Earth Engine (GEE) and used QGIS to cut the large images into smaller tiles for further analysis.
#
# The next step is to calculate additional spectral indices for each tile, such as NDVI, NDBI, mNDWI, and NSPI, which are commonly used in remote sensing to extract information about vegetation, built-up areas, water bodies and soil properties.
#
# Here is what each band represents:
# - B1 to B7: These are the original spectral bands from the satellite imagery (e.g., Landsat or Sentinel), each capturing reflectance in different parts of the electromagnetic spectrum.
# - NDVI (Normalized Difference Vegetation Index): Highlights vegetation by comparing the near-infrared (NIR) and red bands. High NDVI values indicate healthy vegetation.
# - NDBI (Normalized Difference Built-up Index): Used to identify built-up (urban) areas by comparing the shortwave infrared (SWIR) and NIR bands.
# - mNDWI (Modified Normalized Difference Water Index): Enhances open water features by using green and SWIR bands.
# - NSPI_1 and NSPI_2 (Normalized Soil and Plant Indices): These are custom indices designed to highlight specific soil or plant characteristics, depending on the band combinations used.
#
# Calculating these indices allows for more effective classification and analysis of land cover types in each tile.
#
# Note: All of these indices could have been calculated directly within GEE before downloading the data, which would have streamlined the workflow. However, in this case, I am performing the calculations locally after tiling in QGIS.

# %%
# Function for normalized difference index
def norm_diff(band1, band2):
    bottom = band1 + band2
    bottom[bottom == 0] = 1e-10  # avoid division by zero
    return (band1 - band2) / bottom

def quantize(arr, levels=64):
    arr_min = np.nanmin(arr)
    arr_max = np.nanmax(arr)
    scaled = ((arr - arr_min) / (arr_max - arr_min) * (levels - 1)).astype(np.uint8)
    return scaled

def calc_sum_average(arr):
    # Compute GLCM (grey level co-occurrence matrix)
    glcm = graycomatrix(arr, distances=[1], angles=[0], levels=64, symmetric=True, normed=True)
    # sum average is sum over (i+j)*p(i,j)
    i, j = np.ogrid[0:64, 0:64]
    sum_avg = np.sum((i + j) * glcm[:, :, 0, 0])
    return sum_avg


# Loop through each folder in the root directory
for folder_name in os.listdir(root_dir):
    folder_path = os.path.join(root_dir, folder_name)
    if not os.path.isdir(folder_path):
        continue
    print(f"Processing folder: {folder_name}")

    # Find all .tif files in this folder
    tiff_files = glob.glob(os.path.join(folder_path, "*.tif"))
    print(f"Found {len(tiff_files)} tiff files.")

    files_processed = 0
    files_skipped = 0
    files_error = 0

    for tiff_path in tiff_files:
        tiff_name = os.path.basename(tiff_path)
        try:
            with rasterio.open(tiff_path) as src:
                bands = src.read()  # shape = (n_bands, height, width)
                profile = src.profile

            # Check if there are at least 11 bands
            if bands.shape[0] < 11:
                # print(f"Skipping {tiff_name}: not enough bands ({bands.shape[0]})")
                files_skipped += 1
                continue

            # Extract needed bands (adjust indices accordingly)
            B1 = bands[0]
            B2 = bands[1]
            B3 = bands[2]
            B4 = bands[3]
            B5 = bands[4]
            B6 = bands[5]
            B7 = bands[6]
            B8 = bands[7]
            B9 = bands[8]
            B11 = bands[9]
            B12 = bands[10]

            # Calculate indices
            NDVI = norm_diff(B8, B4)
            NDBI = norm_diff(B11, B8)
            mNDWI = norm_diff(B3, B11)
            NSPI_1 = norm_diff(B11, B12)
            NSPI_2 = norm_diff(B11, B9)

            # Prepare list of bands and indices for texture calculation
            textures_input = {
                'B2': B2,
                'B6': B6,
                'B7': B7,
                'NDVI': NDVI,
                'mNDWI': mNDWI,
                'NDBI': NDBI
            }

            textures = {}
            for name, arr in textures_input.items():
                arr_q = quantize(arr)
                sum_avg = calc_sum_average(arr_q)
                textures[name + '_sumAvg'] = sum_avg

            # Create new stack with original bands + indices 
            new_bands = np.stack([B1, B2, B3, B4, B5, B6, B7, NDVI, NDBI, mNDWI, NSPI_1, NSPI_2])

            profile.update(count=len(new_bands), dtype=rasterio.float32)

            # Output file path
            out_name = tiff_name
            output_folder = folder_name + '_with_indices'
            output_folder_path = os.path.join(root_dir, output_folder)
            os.makedirs(output_folder_path, exist_ok=True)
            out_path = os.path.join(output_folder_path, out_name)

            with rasterio.open(out_path, 'w', **profile) as dst:
                for i, band in enumerate(new_bands, start=1):
                    dst.write(band.astype(rasterio.float32), i)

            files_processed += 1

        except Exception as e:
            # print(f"Error processing {tiff_name}: {e}")
            files_error += 1

    print(f"Finished folder: {folder_name} | Processed: {files_processed} | Skipped: {files_skipped} | Errors: {files_error}")

print("Processing complete.")
# Out:
# Processing folder: Augmented
#  Found 170 tiff files.
# C:\Users\charl\AppData\Local\Temp\ipykernel_19188\2918459046.py:10: RuntimeWarning: invalid value encountered in cast
#   scaled = ((arr - arr_min) / (arr_max - arr_min) * (levels - 1)).astype(np.uint8)
# Finished folder: Augmented | Processed: 170 | Skipped: 0 | Errors: 0
# Processing folder: Baihe
#  Found 356 tiff files.
# Finished folder: Baihe | Processed: 356 | Skipped: 0 | Errors: 0
# Processing folder: Cao
#  Found 508 tiff files.
# Finished folder: Cao | Processed: 508 | Skipped: 0 | Errors: 0
# Processing folder: Daming
#  Found 297 tiff files.
# Finished folder: Daming | Processed: 297 | Skipped: 0 | Errors: 0
# Processing folder: Gushi
#  Found 717 tiff files.
# Finished folder: Gushi | Processed: 717 | Skipped: 0 | Errors: 0
# Processing folder: Hanbin
#  Found 1872 tiff files.
# C:\Users\charl\AppData\Local\Temp\ipykernel_19188\2918459046.py:8: RuntimeWarning: All-NaN slice encountered
#   arr_min = np.nanmin(arr)
# C:\Users\charl\AppData\Local\Temp\ipykernel_19188\2918459046.py:9: RuntimeWarning: All-NaN slice encountered
#   arr_max = np.nanmax(arr)
# Finished folder: Hanbin | Processed: 1872 | Skipped: 0 | Errors: 0
# Processing folder: Heshui
#  Found 784 tiff files.
# Finished folder: Heshui | Processed: 784 | Skipped: 0 | Errors: 0
# Processing folder: Jingyang
#  Found 370 tiff files.
# Finished folder: Jingyang | Processed: 370 | Skipped: 0 | Errors: 0
# Processing folder: LanpingBaiandPumi
#  Found 939 tiff files.
# C:\Users\charl\AppData\Local\Temp\ipykernel_19188\2918459046.py:10: RuntimeWarning: invalid value encountered in divide
#   scaled = ((arr - arr_min) / (arr_max - arr_min) * (levels - 1)).astype(np.uint8)
# Finished folder: LanpingBaiandPumi | Processed: 939 | Skipped: 0 | Errors: 0
# Processing folder: Sheqi
#  Found 291 tiff files.
# Finished folder: Sheqi | Processed: 291 | Skipped: 0 | Errors: 0
# Processing folder: Shuangfeng
#  Found 401 tiff files.
# Finished folder: Shuangfeng | Processed: 401 | Skipped: 0 | Errors: 0
# Processing folder: Xuanhua
#  Found 771 tiff files.
# Finished folder: Xuanhua | Processed: 771 | Skipped: 0 | Errors: 0
# Processing folder: Yanjin
#  Found 267 tiff files.
# Finished folder: Yanjin | Processed: 267 | Skipped: 0 | Errors: 0
# Processing folder: Yiyuan
#  Found 471 tiff files.
# Finished folder: Yiyuan | Processed: 471 | Skipped: 0 | Errors: 0
# Processing folder: Yongshan
#  Found 648 tiff files.
# Finished folder: Yongshan | Processed: 648 | Skipped: 0 | Errors: 0
# Processing folder: Yuanling
#  Found 1265 tiff files.
# Finished folder: Yuanling | Processed: 1265 | Skipped: 0 | Errors: 0
# Processing folder: Yuechi
#  Found 358 tiff files.
# Finished folder: Yuechi | Processed: 358 | Skipped: 0 | Errors: 0
# Processing complete.

# %% [markdown]
# ## Annotation

# %%
solar = gpd.read_file('../../data/positive_samples.csv')

# parse WKT strings explicitly
solar['geometry'] = solar['geometry'].apply(shapely.wkt.loads)

# drop Z coordinate
solar['geometry'] = solar['geometry'].apply(lambda g: shapely.wkt.loads(g.wkt))


solar = solar.set_geometry('geometry')
solar.crs = "EPSG:4326"

# %% [markdown]
# ### Piwel-wise labelling and saving metadata

# %%
# storage
records = []
counts = []

# Loop through each folder
for folder_name in os.listdir(root_dir):
    if not folder_name.endswith("_with_indices"):
        continue

    folder_path = os.path.join(root_dir, folder_name)
    if not os.path.isdir(folder_path):
        continue

    county = folder_name.replace("_with_indices", "")
    nb_partial_with = 0
    nb_partial_without = 0

    tiles = [f for f in os.listdir(folder_path) if f.endswith('.tif')]
    for file in tiles:
        tile_path = os.path.join(folder_path, file)
        with rasterio.open(tile_path) as src:
            tile_crs = src.crs
            bounds = src.bounds
            shape = (src.height, src.width)
            transform = src.transform

            # reproject solar to tile CRS
            solar_tile = solar.to_crs(tile_crs)
            tile_geom = box(*bounds)
            solar_clipped = solar_tile[solar_tile.intersects(tile_geom)]

            if len(solar_clipped) == 0:
                 # no solar panels → mask of zeros
                mask = np.zeros(shape, dtype=np.uint8)
                label = 0 #image_wise label 0 = no PV in this tiles 
                nb_partial_without += 1
            else:
                mask = rasterize(
                    [(geom, 1) for geom in solar_clipped.geometry],
                    out_shape=shape,
                    transform=transform,
                    fill=0,
                    dtype=np.uint8
                ) # all pixels inside solar panels polygons = 1 others=0
                label = 1 #PV tiles 
                nb_partial_with += 1

            # save mask
            mask_folder_name = folder_name.replace("_with_indices", "_mask")
            mask_dir = os.path.join(os.path.dirname(folder_path), mask_folder_name)
            os.makedirs(mask_dir, exist_ok=True)
            tile_base = os.path.splitext(file)[0]
            mask_path = os.path.join(mask_dir, f"{tile_base}.tif")
            with rasterio.open(
                mask_path, 'w',
                driver='GTiff',
                height=shape[0],
                width=shape[1],
                count=1,
                dtype=mask.dtype,
                crs=tile_crs,
                transform=transform
            ) as dst:
                dst.write(mask, 1)

            # record
            records.append({
                'tile_path': tile_path,
                'mask_path': mask_path,
                'county': county,
                'label': label
            })

    counts.append({
        'county': county,
        'with_solar': nb_partial_with,
        'without_solar': nb_partial_without,
        'total': nb_partial_with + nb_partial_without
    })

df = pd.DataFrame(records)
df.to_csv("tiles_metadata.csv", index=False)
print("Metadata CSV saved as tiles_metadata.csv")

counts_df = pd.DataFrame(counts)
print("Counts by county:\n")
print(counts_df)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 38
#      36     nb_partial_without += 1
#      37 else:
# ---> 38     mask = rasterize(
#      39         [(geom, 1) for geom in solar_clipped.geometry],
#      40         out_shape=shape,
#      41         transform=transform,
#      42         fill=0,
#      43         dtype=np.uint8
#      44     ) # all pixels inside solar panels polygons = 1 others=0
#      45     label = 1 #PV tiles
#      46     nb_partial_with += 1
#
# File c:\Users\charl\anaconda3\Lib\site-packages\rasterio\env.py:410, in ensure_env.<locals>.wrapper(*args, **kwds)
#     407 @wraps(f)
#     408 def wrapper(*args, **kwds):
#     409     if local._env:
# --> 410         return f(*args, **kwds)
#     411     else:
#     412         with Env.from_defaults():
#
# File c:\Users\charl\anaconda3\Lib\site-packages\rasterio\features.py:311, in rasterize(shapes, out_shape, fill, nodata, masked, out, transform, all_touched, merge_alg, default_value, dtype, skip_invalid, dst_path, dst_kwds)
#     308     geom = item
#     309     value = default_value
# --> 311 geom = getattr(geom, '__geo_interface__', None) or geom
#     313 if is_valid_geom(geom):
#     314     shape_values.append(value)
#
# File c:\Users\charl\anaconda3\Lib\site-packages\shapely\geometry\polygon.py:295, in Polygon.__geo_interface__(self)
#     293 else:
#     294     coords = [tuple(self.exterior.coords)]
# --> 295     for hole in self.interiors:
#     296         coords.append(tuple(hole.coords))
#     297 return {"type": "Polygon", "coordinates": tuple(coords)}
#
# File c:\Users\charl\anaconda3\Lib\site-packages\shapely\geometry\polygon.py:250, in Polygon.interiors(self)
#     248 @property
#     249 def interiors(self):
# --> 250     if self.is_empty:
#     251         return []
#     252     return InteriorRingSequence(self)
#
# File c:\Users\charl\anaconda3\Lib\site-packages\shapely\geometry\base.py:629, in BaseGeometry.is_empty(self)
#     626 @property
#     627 def is_empty(self):
#     628     """True if the set of points in this geometry is empty, else False"""
# --> 629     return bool(shapely.is_empty(self))
#
# File c:\Users\charl\anaconda3\Lib\site-packages\shapely\decorators.py:77, in multithreading_enabled.<locals>.wrapped(*args, **kwargs)
#      75     for arr in array_args:
#      76         arr.flags.writeable = False
# ---> 77     return func(*args, **kwargs)
#      78 finally:
#      79     for arr, old_flag in zip(array_args, old_flags):
#
# File c:\Users\charl\anaconda3\Lib\site-packages\shapely\predicates.py:162, in is_empty(geometry, **kwargs)
#     137 @multithreading_enabled
#     138 def is_empty(geometry, **kwargs):
#     139     """Returns True if a geometry is an empty point, polygon, etc.
#     140
#     141     Parameters
#    (...)
#     160     False
#     161     """
# --> 162     return lib.is_empty(geometry, **kwargs)
#
# KeyboardInterrupt:

# %%
df = pd.read_csv("tiles_metadata.csv")

# %%
# Filter for positive, non-augmented tiles
df_filtered = df[(df['label'] == 1) & (df['county'] != "Augmented")]

if len(df_filtered) == 0:
    print("No positive, non-augmented tiles found.")
else:
    row = df_filtered.iloc[0]  # Use the first such tile
    with rasterio.open(row['tile_path']) as src:
        tile_img = src.read()  # shape: (bands, H, W)
        if tile_img.shape[0] >= 4:
            blue = tile_img[0]
            green = tile_img[1]
            red = tile_img[2]
        else:
            raise ValueError("Tile does not have at least 4 bands (B2,B3,B4,B8) for 10m resolution.")

    # Normalize bands for display
    def normalize(band):
        band_min, band_max = np.nanmin(band), np.nanmax(band)
        return np.clip((band - band_min) / (band_max - band_min + 1e-8), 0, 1)

    blue_disp = normalize(blue)
    green_disp = normalize(green)
    red_disp = normalize(red)

    # Stack for RGB (R,G,B)
    rgb = np.stack([red_disp, green_disp, blue_disp], axis=-1)

    plt.figure(figsize=(6, 6))
    plt.imshow(rgb)
    plt.title(f"Tile: {row['county']} - RGB (B2,B3,B4)")
    plt.axis('off')
    plt.tight_layout()
    plt.show()

# %%
df = df[(df['label'] == 1) & (df['county'] != "Augmented")]

# Only use the 10m resolution bands: Sentinel-2 bands B2 (Blue), B3 (Green), B4 (Red), B8 (NIR)
# Band order in Sentinel-2 L2A 10m: [B2, B3, B4, B8] = [Blue, Green, Red, NIR]
# We'll plot: Blue, Green, Red, RGB, NIR, Mask
num_examples = 3
num_examples = min(num_examples, len(df))

num_cols = 6
col_titles = ['Blue (B2)', 'Green (B3)', 'Red (B4)', 'RGB (B2,B3,B4)', 'NIR (B8)', 'Mask']

fig, axs = plt.subplots(num_examples, num_cols, figsize=(20, 6 * num_examples))

for i in range(num_examples):
    row = df.iloc[i]
    # Read the image tile (all bands)
    with rasterio.open(row['tile_path']) as src:
        tile_img = src.read()  # shape: (bands, H, W)
        # Only keep the 10m bands: B2 (Blue), B3 (Green), B4 (Red), B8 (NIR)
        # Assume band order is [B2, B3, B4, B8] (0,1,2,3)
        if tile_img.shape[0] >= 4:
            blue = tile_img[0]
            green = tile_img[1]
            red = tile_img[2]
            nir = tile_img[3]
        else:
            raise ValueError("Tile does not have at least 4 bands (B2,B3,B4,B8) for 10m resolution.")

    # Read the mask
    with rasterio.open(row['mask_path']) as src:
        mask_img = src.read(1)

    # Plot Blue (B2)
    ax = axs[i, 0] if num_examples > 1 else axs[0]
    b_min, b_max = np.nanmin(blue), np.nanmax(blue)
    blue_disp = (blue - b_min) / (b_max - b_min + 1e-8)
    blue_disp = np.clip(blue_disp, 0, 1)
    im_blue = ax.imshow(blue_disp, cmap='gray')
    ax.set_title(f"Tile {i}: {row['county']} - {col_titles[0]}")
    ax.axis('off')
    if i == 0:
        cbar = fig.colorbar(im_blue, ax=ax, fraction=0.046, pad=0.04)
        cbar.set_label('Reflectance (Blue)', fontsize=12)

    # Plot Green (B3)
    ax = axs[i, 1] if num_examples > 1 else axs[1]
    g_min, g_max = np.nanmin(green), np.nanmax(green)
    green_disp = (green - g_min) / (g_max - g_min + 1e-8)
    green_disp = np.clip(green_disp, 0, 1)
    im_green = ax.imshow(green_disp, cmap='gray')
    ax.set_title(f"Tile {i}: {row['county']} - {col_titles[1]}")
    ax.axis('off')
    if i == 0:
        cbar = fig.colorbar(im_green, ax=ax, fraction=0.046, pad=0.04)
        cbar.set_label('Reflectance (Green)', fontsize=12)

    # Plot Red (B4)
    ax = axs[i, 2] if num_examples > 1 else axs[2]
    r_min, r_max = np.nanmin(red), np.nanmax(red)
    red_disp = (red - r_min) / (r_max - r_min + 1e-8)
    red_disp = np.clip(red_disp, 0, 1)
    im_red = ax.imshow(red_disp, cmap='gray')
    ax.set_title(f"Tile {i}: {row['county']} - {col_titles[2]}")
    ax.axis('off')
    if i == 0:
        cbar = fig.colorbar(im_red, ax=ax, fraction=0.046, pad=0.04)
        cbar.set_label('Reflectance (Red)', fontsize=12)

    # Plot RGB composite (B2, B3, B4)
    ax_rgb = axs[i, 3] if num_examples > 1 else axs[3]
    rgb = np.stack([red_disp, green_disp, blue_disp], axis=-1)  # RGB order for display
    im_rgb = ax_rgb.imshow(rgb)
    ax_rgb.set_title(f"Tile {i}: {row['county']} - {col_titles[3]}")
    ax_rgb.axis('off')
    if i == 0:
        # Add a legend for RGB
        red_patch = mpatches.Patch(color='red', label='Red (B4)')
        green_patch = mpatches.Patch(color='green', label='Green (B3)')
        blue_patch = mpatches.Patch(color='blue', label='Blue (B2)')
        ax_rgb.legend(handles=[red_patch, green_patch, blue_patch], loc='lower right', fontsize=10, frameon=True)

    # Plot NIR (B8)
    ax_nir = axs[i, 4] if num_examples > 1 else axs[4]
    nir_min, nir_max = np.nanmin(nir), np.nanmax(nir)
    nir_disp = (nir - nir_min) / (nir_max - nir_min + 1e-8)
    nir_disp = np.clip(nir_disp, 0, 1)
    im_nir = ax_nir.imshow(nir_disp, cmap='gray')
    ax_nir.set_title(f"Tile {i}: {row['county']} - {col_titles[4]}")
    ax_nir.axis('off')
    if i == 0:
        cbar = fig.colorbar(im_nir, ax=ax_nir, fraction=0.046, pad=0.04)
        cbar.set_label('Reflectance (NIR)', fontsize=12)

    # Plot mask as 0 and 1
    ax_mask = axs[i, 5] if num_examples > 1 else axs[5]
    im_mask = ax_mask.imshow(mask_img, cmap='gray', vmin=0, vmax=1)
    ax_mask.set_title(f"Tile {i}: {row['county']} - {col_titles[5]}")
    ax_mask.axis('off')
    if i == 0:
        mask_1 = mpatches.Patch(color='white', label='PV Area (1)')
        mask_0 = mpatches.Patch(color='black', label='Background (0)')
        ax_mask.legend(handles=[mask_1, mask_0], loc='lower right', fontsize=10, frameon=True)

# Set column titles
for c in range(num_cols):
    if num_examples > 1:
        axs[0, c].set_title(col_titles[c], fontsize=16)
    else:
        axs[c].set_title(col_titles[c], fontsize=16)

plt.tight_layout()
plt.show()

# %%
# Calculate the center coordinates of each validation tile and print a Google Maps link for visual inspection.
num_tiles = 3

for i in range(num_tiles):
    row = df.iloc[i]
    tile_path = row['tile_path']
    with rasterio.open(tile_path) as src:
        # Get the bounds of the raster
        bounds = src.bounds
        # Calculate the center coordinates in the raster CRS
        center_x = (bounds.left + bounds.right) / 2
        center_y = (bounds.top + bounds.bottom) / 2
        
        # If CRS is not WGS84, transform
        if src.crs != "EPSG:4326":
            lon, lat = transform(
                src.crs, "EPSG:4326", [center_x], [center_y]
            )
            center_lon = lon[0]
            center_lat = lat[0]
        else:
            center_lon = center_x
            center_lat = center_y
        
        # Print the file path and Google Maps link
        print(f"Tile {i+1} path: {tile_path}")
        print(f"Center: lat={center_lat:.6f}, lon={center_lon:.6f}")
        print(f"Google Maps: https://www.google.com/maps?q={center_lat:.6f},{center_lon:.6f}\n")
# Out:
# Tile 1 path: D:\solar-data-china\tiles\Cao_with_indices\s2_Cao-0000000000-0000000000_10_18.tif
# Center: lat=34.882686, lon=115.528196
# Google Maps: https://www.google.com/maps?q=34.882686,115.528196
#
# Tile 2 path: D:\solar-data-china\tiles\Cao_with_indices\s2_Cao-0000000000-0000000000_11_18.tif
# Center: lat=34.863819, lon=115.528196
# Google Maps: https://www.google.com/maps?q=34.863819,115.528196
#
# Tile 3 path: D:\solar-data-china\tiles\Cao_with_indices\s2_Cao-0000000000-0000004864_14_02.tif
# Center: lat=34.807191, lon=115.597187
# Google Maps: https://www.google.com/maps?q=34.807191,115.597187

# %% [markdown]
# ### Balanced dataset

# %% [markdown]
# For each prefecture, we will take all the positive samples. To make the training dataset balanced across prefectures, we will select a proportional number of non-PV tiles relative to the total number of tiles.

# %%
# Exclude 'Augmented' from proportional calculation
counts_no_aug = counts_df[counts_df['county'] != 'Augmented']

total_tiles = counts_no_aug['total'].sum()
total_positive = counts_no_aug['with_solar'].sum()
total_negative = counts_no_aug['without_solar'].sum()

# Calculate proportion only for non-augmented counties
counts_df['proportion'] = counts_df.apply(
    lambda row: row['total'] / total_tiles if row['county'] != 'Augmented' else None, axis=1
)

# Calculate proportional columns for non-augmented, but for 'Augmented' just copy with_solar/without_solar
counts_df['proportional_pv'] = counts_df.apply(
    lambda row: int(round(total_positive * row['proportion'])) if row['county'] != 'Augmented' else row['with_solar'],
    axis=1
)

counts_df['proportional_nopv'] = counts_df.apply(
    lambda row: int(round(total_negative * row['proportion'])) if row['county'] != 'Augmented' else row['without_solar'],
    axis=1
)

# For nb_nopv: for each county, take the minimum between the available 'without_solar' panels and twice the proportional number of non-PV tiles (scaled by the overall PV/non-PV ratio). 
# This ensures that for each county, we do not select more non-PV tiles than are available, and we limit the number to avoid excessive class imbalance.
ratio = counts_df['with_solar'].sum() / counts_df['without_solar'].sum()
counts_df['nb_nopv'] = counts_df.apply(
    lambda row: (min(row['without_solar'], 2 * int(round(row['proportional_nopv'] * ratio)))) if row['county'] != 'Augmented' else 0,
    axis=1
)


# If the number of PV tiles is smaller than the proportional PV needed, mark True so the model knows to perform augmentation during training
counts_df['transformation'] = counts_df.apply(
    lambda row: (row['with_solar'] < row['proportional_pv']) if row['county'] != 'Augmented' else False,
    axis=1
)

counts_df
# Out:
#                county  with_solar  without_solar  total  proportion  \
# 0           Augmented         164              6    170         NaN
# 1               Baihe           0            356    356    0.034513
# 2                 Cao          12            496    508    0.049249
# 3              Daming           8            289    297    0.028793
# 4               Gushi           5            712    717    0.069510
# 5              Hanbin           1           1871   1872    0.181483
# 6              Heshui           1            783    784    0.076006
# 7            Jingyang           0            370    370    0.035870
# 8   LanpingBaiandPumi           4            935    939    0.091032
# 9               Sheqi           0            291    291    0.028211
# 10         Shuangfeng           0            401    401    0.038875
# 11            Xuanhua          52            719    771    0.074746
# 12             Yanjin           3            264    267    0.025885
# 13             Yiyuan          11            460    471    0.045662
# 14           Yongshan           0            648    648    0.062821
# 15           Yuanling           0           1265   1265    0.122637
# 16             Yuechi           0            358    358    0.034707
#
#     proportional_pv  proportional_nopv  nb_nopv  transformation
# 0               164                  6        0           False
# 1                 3                353       18            True
# 2                 5                503       26           False
# 3                 3                294       16           False
# 4                 7                710       36            True
# 5                18               1854       94            True
# 6                 7                777       40            True
# 7                 3                367       18            True
# 8                 9                930       48            True
# 9                 3                288       14            True
# 10                4                397       20            True
# 11                7                764       40           False
# 12                3                264       14           False
# 13                4                467       24           False
# 14                6                642       32            True
# 15               12               1253       64            True
# 16                3                355       18            True

# %%
counts_df.sum()
# Out:
# county               AugmentedBaiheCaoDamingGushiHanbinHeshuiJingya...
# with_solar                                                         261
# without_solar                                                    10224
# total                                                            10485
# proportion                                                         1.0
# proportional_pv                                                    261
# proportional_nopv                                                10224
# nb_nopv                                                            522
# transformation                                                      11
# dtype: object

# %%
counts_df.to_csv("tiles_proportion.csv", index=False)
